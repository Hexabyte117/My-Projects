# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as manimation

# %%
n = 1000
x = np.linspace(0, 6*np.pi, n)
y = np.sin(x)

# Define the meta data for the movie
FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title='Movie Test', artist='Matplotlib',
                comment='a red circle following a blue sine wave')
writer = FFMpegWriter(fps=15, metadata=metadata)

# Initialize the movie
fig = plt.figure()

# plot the sine wave line
sine_line, = plt.plot(x, y, 'b')
red_circle, = plt.plot([], [], 'ro', markersize = 10)
plt.xlabel('x')
plt.ylabel('sin(x)')

# Update the frames for the movie
with writer.saving(fig, "writer_test.mp4", 100):
    for i in range(n):
        x0 = x[i]
        y0 = y[i]
        red_circle.set_data(x0, y0)
        writer.grab_frame()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20128\318095239.py in <module>
#       4
#       5 # Define the meta data for the movie
# ----> 6 FFMpegWriter = manimation.writers['ffmpeg']
#       7 metadata = dict(title='Movie Test', artist='Matplotlib',
#       8                 comment='a red circle following a blue sine wave')
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in __getitem__(self, name)
#     149         if self.is_available(name):
#     150             return self._registered[name]
# --> 151         raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#     152
#     153
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %%
# don't worry about the code in this cell, it is just to let you 
# display the movies you generated above in Jupyter notebook
from IPython.display import HTML

HTML("""
<div align="middle">
<video width="80%" controls>
      <source src="writer_test.mp4" type="video/mp4">
</video></div>""")
# Out:
# <div align="middle">
# <video width="80%" controls>
#       <source src="writer_test.mp4" type="video/mp4">
# </video></div>

# %%
FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title='Movie Test', artist='Matplotlib',
                comment='a red circle following a blue sine wave')
writer = FFMpegWriter(fps=15, metadata=metadata)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20128\26905440.py in <module>
# ----> 1 FFMpegWriter = manimation.writers['ffmpeg']
#       2 metadata = dict(title='Movie Test', artist='Matplotlib',
#       3                 comment='a red circle following a blue sine wave')
#       4 writer = FFMpegWriter(fps=15, metadata=metadata)
#
# ~\Anaconda3\lib\site-packages\matplotlib\animation.py in __getitem__(self, name)
#     149         if self.is_available(name):
#     150             return self._registered[name]
# --> 151         raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#     152
#     153
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %%
fig = plt.figure()

# plot the sine wave line
sine_line, = plt.plot(x, y, 'b')
red_circle, = plt.plot([], [], 'ro', markersize = 10)
plt.xlabel('x')
plt.ylabel('sin(x)')
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
with writer.saving(fig, "writer_test.mp4", 100):
    for i in range(n):
        x0 = x[i]
        y0 = y[i]
        red_circle.set_data(x0, y0)
        writer.grab_frame()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20128\1897883057.py in <module>
# ----> 1 with writer.saving(fig, "writer_test.mp4", 100):
#       2     for i in range(n):
#       3         x0 = x[i]
#       4         y0 = y[i]
#       5         red_circle.set_data(x0, y0)
#
# NameError: name 'writer' is not defined
